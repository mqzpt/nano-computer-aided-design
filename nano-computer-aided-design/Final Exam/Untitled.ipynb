# %%
import numpy as np
# Q3 - long cylinder fr

r1 = 0.05
r2 = 0.1
k = 14
Q = 1000
BC1 = 120

# number of interior nodes is n
n = 6
r = np.linspace(r1, r2, n+2)
#need dr for formula
dr = r[1] - r[0]

A = np.diag(-2*np.ones(n-1)) + \
    np.diag(1-dr/(2*ri[1:]), -1) + \
    np.diag(1+(dr/2*ri[:-1]), 1)

B = np.zeros(n-1)
B[0]=BC1*((dr/2*ri[0])-1)

# %%
ri[0]
# Out:
# 0.060000000000000005

# %%
r[1]
# Out:
# 0.060000000000000005
