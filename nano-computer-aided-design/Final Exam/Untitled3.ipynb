# %%
# question 6
from scipy.integrate import solve_ivp,solve_bvp
import matplotlib.pyplot as plt
import numpy as np

a = 0.081
dx = 2
T0 = 10 - 14*(np.cos(2*np.pi/365 * (t-37)))

def dTdt(t, T):
    dTdt = np.zeros((T.size))
    dTdt[0] = a/(dx**2) * (T[1] - 2*T[0] + T0)
    dTdt[1:-1] = a/(dx**2) * (T[:-2] - 2*T[1:-1] + T[2:])
    dTdt[-1] = a * (2*
